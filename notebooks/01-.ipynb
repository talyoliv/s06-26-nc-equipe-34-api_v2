# %%
import pandas as pd

antenas = pd.read_csv(""
    "dataset-visent/referencias/antenas.csv",
    dtype={"ecgi": str}
)

assinantes = pd.read_csv(
    "dataset-visent/referencias/assinantes.csv"
)

concentracao = pd.read_csv(
    "dataset-visent/tensores/tensor_concentracao.csv",
    dtype={"ecgi": str}
)

od = pd.read_csv(
    "dataset-visent/tensores/tensor_od.csv"
)

fluxo_vias = pd.read_csv(
    "dataset-visent/tensores/tensor_fluxo_vias.csv",
    dtype={
        "ecgi_origem": str,
        "ecgi_destino": str
    }
)
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
